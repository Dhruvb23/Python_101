# %%
#Question 1
print("Hello World!\nHave a good day.\nLearning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
#Question 2 
print("Hello");print("Have a good day.");print("Learning Python is fun!")
# Out:
# Hello
# Have a good day.
# Learning Python is fun!

# %%
#Question 3
x=25
print("I am",x, "years old")
# Out:
# I am 25 years old

# %%
#Question 4
name=input("Enter your name: ")
age=input("Enter your age")
print("Name:", name)
print("Age:", age)
# Out:
# Name: dhruv
# Age: 19

# %%
#Question 5
x,y,z="Apple","Mango","Banana"
print(x,y,z)
# Out:
# Apple Mango Banana

# %%
#Question 6 part 1
x=5
y=str(x)
print(type(y))
print(y)

#Part 2
a=(int(7.8))
print("7.8 as an integer:", a)

#part 3 
b=float(9)
print("9 as float:",b)
# Out:
# <class 'str'>
# 5
# 7.8 as an integer: 7
# 9 as float: 9.0

# %%
#Question 7
x=10
y=str(x)
print(x, type(y))
# Out:
# 10 <class 'str'>

# %%
#Question 8
x=20
y=float(x)
print(x, type(y))
# Out:
# 20 <class 'float'>
